# %%
import pandas as pd
import numpy as np
import requests
import csv
from config import api_key

# %%
# data path
# url="https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv"
# response=requests.get(url)

df=pd.read_csv("https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv")
df.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2019-11-16T13:39:14.330Z  35.781166 -117.588837  17.94  1.58      ml  11.0
# 1  2019-11-16T13:38:43.520Z  37.619499 -118.841499   3.39  1.28      md  16.0
# 2  2019-11-16T13:37:27.000Z  35.804333 -117.627167   5.21  2.20      ml  30.0
# 3  2019-11-16T13:36:18.262Z  60.305600 -151.512900  57.90  1.70      ml   NaN
# 4  2019-11-16T13:33:37.560Z  35.673667 -117.568667   4.41  1.58      ml  27.0
#
#      gap     dmin   rms  ...                   updated  \
# 0  154.0  0.03521  0.15  ...  2019-11-16T13:41:25.132Z
# 1  139.0  0.01152  0.03  ...  2019-11-16T13:40:20.728Z
# 2   56.0  0.02666  0.16  ...  2019-11-16T13:41:23.132Z
# 3    NaN      NaN  0.45  ...  2019-11-16T13:40:07.498Z
# 4   48.0  0.09638  0.18  ...  2019-11-16T13:37:32.111Z
#
#                             place        type horizontalError depthError  \
# 0    17km W of Searles Valley, CA  earthquake            1.06       1.66
# 1     12km E of Mammoth Lakes, CA  earthquake            0.38       0.62
# 2  21km WNW of Searles Valley, CA  earthquake            0.21       0.65
# 3       13km WSW of Cohoe, Alaska  earthquake             NaN       0.90
# 4      11km ENE of Ridgecrest, CA  earthquake            0.25       0.68
#
#    magError  magNst     status  locationSource magSource
# 0     0.224     5.0  automatic              ci        ci
# 1     0.150    15.0  automatic              nc        nc
# 2     0.137    25.0  automatic              ci        ci
# 3       NaN     NaN  automatic              ak        ak
# 4     0.148    26.0  automatic              ci        ci
#
# [5 rows x 22 columns]
